# %%
from scipy.datasets import electrocardiogram
ecg = electrocardiogram()
ecg
# Out:
# array([-0.245, -0.215, -0.185, ..., -0.405, -0.395, -0.385],
#       shape=(108000,))

# %%
type(ecg)
# Out:
# numpy.ndarray

# %%
ecg.shape, ecg.mean(), ecg.std()
# Out:
# ((108000,), np.float64(-0.16510875), np.float64(0.5992473991177295))

# %%
ecg.size
# Out:
# 108000

# %%
import numpy as np
import matplotlib.pyplot as plt

fs = 360
time = np.arange(ecg.size) / fs
plt.plot(time, ecg)
plt.xlabel("time in s")
plt.ylabel("ECG in mV")
plt.xlim(9, 10.2)
plt.ylim(-1, 1.5)
plt.show()

# %%
plt.plot(time, ecg)
plt.xlabel("time in s")
plt.ylabel("ECG in mV")
plt.xlim(46.5, 50)
plt.ylim(-2, 1.5)
plt.show()

# %%
plt.plot(time, ecg)
plt.xlabel("time in s")
plt.ylabel("ECG in mV")
plt.xlim(207, 215)
plt.ylim(-2, 3.5)
plt.show()

# %%
import sounddevice
from scipy.io.wavfile import write
fs= 44100
second = int(input("enter time duration in second:"))
print("recording...")
record_voice= sounddevice.rec(int(second * fs), samplerate=fs, channels=1)
sounddevice.wait()
write("output.wav", fs, record_voice)
print("recording complete")
# Out:
# recording...
# ---------------------------------------------------------------------------
# PortAudioError                            Traceback (most recent call last)
# Cell In[8], line 6
#       2 from scipy.io.wavfile import write
#       3 fs= 44100
#       4 second = int(input("enter time duration in second:"))
#       5 print("recording...")
# ----> 6 record_voice= sounddevice.rec(int(second * fs), samplerate=fs, channels=1)
#       7 sounddevice.wait()
#       8 write("output.wav", fs, record_voice)
#       9 print("recording complete")
#
# File ~/fsb-dsp/.venv/lib/python3.12/site-packages/sounddevice.py:284, in rec(frames, samplerate, channels, dtype, out, mapping, blocking, **kwargs)
#     281     ctx.read_indata(indata)
#     282     ctx.callback_exit()
# --> 284 ctx.start_stream(InputStream, samplerate, ctx.input_channels,
#     285                  ctx.input_dtype, callback, blocking, **kwargs)
#     286 return out
#
# File ~/fsb-dsp/.venv/lib/python3.12/site-packages/sounddevice.py:2664, in _CallbackContext.start_stream(self, StreamClass, samplerate, channels, dtype, callback, blocking, **kwargs)
#    2661 def start_stream(self, StreamClass, samplerate, channels, dtype, callback,
#    2662                  blocking, **kwargs):
#    2663     stop()  # Stop previous playback/recording
# -> 2664     self.stream = StreamClass(samplerate=samplerate,
#    2665                               channels=channels,
#    2666                               dtype=dtype,
#    2667                               callback=callback,
#    2668                               finished_callback=self.finished_callback,
#    2669                               **kwargs)
#    2670     self.stream.start()
#    2671     global _last_callback
#
# File ~/fsb-dsp/.venv/lib/python3.12/site-packages/sounddevice.py:1457, in InputStream.__init__(self, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback)
#    1425 def __init__(self, samplerate=None, blocksize=None,
#    1426              device=None, channels=None, dtype=None, latency=None,
#    1427              extra_settings=None, callback=None, finished_callback=None,
#    1428              clip_off=None, dither_off=None, never_drop_input=None,
#    1429              prime_output_buffers_using_stream_callback=None):
#    1430     """PortAudio input stream (using NumPy).
#    1431
#    1432     This has the same methods and attributes as `Stream`, except
#    (...)   1455
#    1456     """
# -> 1457     _StreamBase.__init__(self, kind='input', wrap_callback='array',
#    1458                          **_remove_self(locals()))
#
# File ~/fsb-dsp/.venv/lib/python3.12/site-packages/sounddevice.py:833, in _StreamBase.__init__(self, kind, samplerate, blocksize, device, channels, dtype, latency, extra_settings, callback, finished_callback, clip_off, dither_off, never_drop_input, prime_output_buffers_using_stream_callback, userdata, wrap_callback)
#     830         samplerate = isamplerate
#     831 else:
#     832     parameters, self._dtype, self._samplesize, samplerate = \
# --> 833         _get_stream_parameters(kind, device, channels, dtype, latency,
#     834                                extra_settings, samplerate)
#     835     self._device = parameters.device
#     836     self._channels = parameters.channelCount
#
# File ~/fsb-dsp/.venv/lib/python3.12/site-packages/sounddevice.py:2750, in _get_stream_parameters(kind, device, channels, dtype, latency, extra_settings, samplerate)
#    2747 if samplerate is None:
#    2748     samplerate = default.samplerate
# -> 2750 info = query_devices(device)
#    2751 if channels is None:
#    2752     channels = info['max_' + kind + '_channels']
#
# File ~/fsb-dsp/.venv/lib/python3.12/site-packages/sounddevice.py:577, in query_devices(device, kind)
#     575 info = _lib.Pa_GetDeviceInfo(device)
#     576 if not info:
# --> 577     raise PortAudioError(f'Error querying device {device}')
#     578 assert info.structVersion == 2
#     579 name_bytes = _ffi_string(info.name)
#
# PortAudioError: Error querying device -1

# %%
sounddevice.query_devices()

# %%
import sounddevice as sd 
import soundfile as sf 

filename = 'output.wav'

data,fs = sf.read(filename, dtype='float32')
sd.play(data, fs)
status = sd.wait()

# %%
from IPython.display import Audio
Audio(data, rate=fs, autoplay=True)

# %%
type(data)

# %%
data.shape

# %%
fs = 44100
time = np.arange(data.size) / fs
plt.plot(time, data)
plt.xlabel("time in s")
plt.ylabel("amplitude")
plt.xlim(0.5, 0.6)
plt.ylim(-1.5, 1.5)
plt.show()

# %%
import numpy as np
import cmath
import math
import matplotlib.pyplot as plt

# %%
cmath.sqrt(-1)

# %%
z = 2 + 3j
print(z)

# %%
print(np.real(z))
print(np.imag(z))
print(np.abs(z))
print(np.angle(z))

# %%
# plot the complex number
plt.plot(np.real(z),np.imag(z), 'ks')

# make plot look nicer
plt.xlim([-5,5])
plt.ylim([-5,5])
plt.plot([-5,5], [0,0],'k')
plt.plot([0,0], [-5,5],'k')
plt.xlabel('real axis')
plt.ylabel('imag axis')
plt.show()

# %%
mag = np.abs(z)
ang = np.angle(z)

plt.polar([0, ang], [0, mag], 'r')
plt.show()

# %%
p = [1, 0, 0, 1]
np.roots(p)
